# %%
import numpy as np

# %%
A = np.linspace(1,2,16).reshape((4,4))**4
b = np.arange(1,5)**2

# %%
np.linalg.solve(A,b)
# Out:
# array([ -659.20886778,  1669.04247482, -1410.82806788,   398.89572244])
